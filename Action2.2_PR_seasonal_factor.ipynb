# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
#加载数据并提取时间特征
def add_timestamp(data):
    #时间维度解析
    data["report_date"] = pd.to_datetime(data["report_date"],format ="%Y%m%d")
    data["year"] = data["report_date"].dt.year
    data["month"] = data["report_date"].dt.month
    data["day"] = data["report_date"].dt.day
    data["week"] = data["report_date"].dt.week
    data["weekday"] = data["report_date"].dt.weekday
    return data   

def data_load():
    data = pd.read_csv("./user_balance_table.csv")
    data = add_timestamp(data)
    return data

# %%
data = data_load()
data
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#          user_id report_date  tBalance  yBalance  total_purchase_amt  \
# 0              1  2014-08-05     20385     20383                   2
# 1              1  2014-08-08     20391     20389                   2
# 2              1  2014-08-11     20397     20395                   2
# 3              1  2014-08-14     20403     20401                   2
# 4              1  2014-08-17     20409     20407                   2
# ...          ...         ...       ...       ...                 ...
# 2840416    28033  2014-08-25    550646    550585                  61
# 2840417    28033  2014-08-31    525707    538147                  60
# 2840418    28033  2014-07-24  20487121  20484824                2297
# 2840419    28033  2014-07-27  20462288  20491722                2298
# 2840420    28035  2014-03-05         0         0                   0
#
#          direct_purchase_amt  purchase_bal_amt  purchase_bank_amt  \
# 0                          0                 0                  0
# 1                          0                 0                  0
# 2                          0                 0                  0
# 3                          0                 0                  0
# 4                          0                 0                  0
# ...                      ...               ...                ...
# 2840416                    0                 0                  0
# 2840417                    0                 0                  0
# 2840418                    0                 0                  0
# 2840419                    0                 0                  0
# 2840420                    0                 0                  0
#
#          total_redeem_amt  consume_amt  ...  share_amt  category1  category2  \
# 0                       0            0  ...          2        NaN        NaN
# 1                       0            0  ...          2        NaN        NaN
# 2                       0            0  ...          2        NaN        NaN
# 3                       0            0  ...          2        NaN        NaN
# 4                       0            0  ...          2        NaN        NaN
# ...                   ...          ...  ...        ...        ...        ...
# 2840416                 0            0  ...         61        NaN        NaN
# 2840417             12500        12500  ...         60        0.0        0.0
# 2840418                 0            0  ...       2297        NaN        NaN
# 2840419             31732            0  ...       2298        NaN        NaN
# 2840420                 0            0  ...          0        NaN        NaN
#
#          category3  category4  year  month  day  week  weekday
# 0              NaN        NaN  2014      8    5    32        1
# 1              NaN        NaN  2014      8    8    32        4
# 2              NaN        NaN  2014      8   11    33        0
# 3              NaN        NaN  2014      8   14    33        3
# 4              NaN        NaN  2014      8   17    33        6
# ...            ...        ...   ...    ...  ...   ...      ...
# 2840416        NaN        NaN  2014      8   25    35        0
# 2840417        0.0    12500.0  2014      8   31    35        6
# 2840418        NaN        NaN  2014      7   24    30        3
# 2840419        NaN        NaN  2014      7   27    30        6
# 2840420        NaN        NaN  2014      3    5    10        2
#
# [2840421 rows x 23 columns]

# %%
#查看weekday,0代表周一
data["weekday"].value_counts()
# Out:
# 6    410701
# 5    408824
# 4    407509
# 3    405907
# 2    404159
# 1    402536
# 0    400785
# Name: weekday, dtype: int64

# %%
#得到稳定期数据
def get_total_balance(data,date):
    #拷贝数据
    df_temp = data.copy()
    #按照report_date聚合求purchase,redeem
    df_temp = df_temp.groupby(["report_date"])["total_purchase_amt","total_redeem_amt"].sum()
    #还原report_date字段，重新索引
    df_temp.reset_index(inplace = True)
    #筛选日期大于等于date的数据
    df_temp = df_temp[df_temp["report_date"]>=date].reset_index(drop = True)
    return df_temp

# %%
#筛选稳定期数据
total_balance = get_total_balance(data,"2014-03-01")
total_balance
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#     report_date  total_purchase_amt  total_redeem_amt
# 0    2014-03-01           362865580         211279011
# 1    2014-03-02           276202230         246199417
# 2    2014-03-03           505305862         513017360
# 3    2014-03-04           524146340         250562978
# 4    2014-03-05           454295491         209072753
# ..          ...                 ...               ...
# 179  2014-08-27           302194801         468164147
# 180  2014-08-28           245082751         297893861
# 181  2014-08-29           267554713         273756380
# 182  2014-08-30           199708772         196374134
# 183  2014-08-31           275090213         292943033
#
# [184 rows x 3 columns]

# %%
#total_balance备份
total_balance_copy = total_balance.copy()

# %%
#生成测试数据
def generate_test_data(data):
    #拷贝数据
    total_balance = data.copy()
    #生成2014年9月1日至2014年9月30日数据
    start = datetime.datetime(2014,9,1)
    end = datetime.datetime(2014,10,1)
    test_data = []
    while start != end:
        #3个字段：report_date,total_purchase_amt,total_redeem_amt
        temp = [start,np.nan,np.nan]
        test_data.append(temp)
        #start日期加1
        start += datetime.timedelta(days =1)
    #封装test_data
    test_data = pd.DataFrame(test_data)
    test_data.columns = total_balance.columns
    #合并total_balance,test_data
    total_balance = pd.concat([total_balance,test_data],axis = 0)    
    return total_balance.reset_index(drop = True)

# %%
#生成测试数据
test_data = generate_test_data(total_balance)
test_data
# Out:
#     report_date  total_purchase_amt  total_redeem_amt
# 0    2014-03-01         362865580.0       211279011.0
# 1    2014-03-02         276202230.0       246199417.0
# 2    2014-03-03         505305862.0       513017360.0
# 3    2014-03-04         524146340.0       250562978.0
# 4    2014-03-05         454295491.0       209072753.0
# ..          ...                 ...               ...
# 209  2014-09-26                 NaN               NaN
# 210  2014-09-27                 NaN               NaN
# 211  2014-09-28                 NaN               NaN
# 212  2014-09-29                 NaN               NaN
# 213  2014-09-30                 NaN               NaN
#
# [214 rows x 3 columns]

# %%
#test_data添加时间维度
test_data = add_timestamp(test_data)
test_data
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#     report_date  total_purchase_amt  total_redeem_amt  year  month  day  week  \
# 0    2014-03-01         362865580.0       211279011.0  2014      3    1     9
# 1    2014-03-02         276202230.0       246199417.0  2014      3    2     9
# 2    2014-03-03         505305862.0       513017360.0  2014      3    3    10
# 3    2014-03-04         524146340.0       250562978.0  2014      3    4    10
# 4    2014-03-05         454295491.0       209072753.0  2014      3    5    10
# ..          ...                 ...               ...   ...    ...  ...   ...
# 209  2014-09-26                 NaN               NaN  2014      9   26    39
# 210  2014-09-27                 NaN               NaN  2014      9   27    39
# 211  2014-09-28                 NaN               NaN  2014      9   28    39
# 212  2014-09-29                 NaN               NaN  2014      9   29    40
# 213  2014-09-30                 NaN               NaN  2014      9   30    40
#
#      weekday
# 0          5
# 1          6
# 2          0
# 3          1
# 4          2
# ..       ...
# 209        4
# 210        5
# 211        6
# 212        0
# 213        1
#
# [214 rows x 8 columns]

# %%
#total_balance添加时间维度
total_balance = total_balance_copy
total_balance = add_timestamp(total_balance)
total_balance
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#     report_date  total_purchase_amt  total_redeem_amt  year  month  day  week  \
# 0    2014-03-01           362865580         211279011  2014      3    1     9
# 1    2014-03-02           276202230         246199417  2014      3    2     9
# 2    2014-03-03           505305862         513017360  2014      3    3    10
# 3    2014-03-04           524146340         250562978  2014      3    4    10
# 4    2014-03-05           454295491         209072753  2014      3    5    10
# ..          ...                 ...               ...   ...    ...  ...   ...
# 179  2014-08-27           302194801         468164147  2014      8   27    35
# 180  2014-08-28           245082751         297893861  2014      8   28    35
# 181  2014-08-29           267554713         273756380  2014      8   29    35
# 182  2014-08-30           199708772         196374134  2014      8   30    35
# 183  2014-08-31           275090213         292943033  2014      8   31    35
#
#      weekday
# 0          5
# 1          6
# 2          0
# 3          1
# 4          2
# ..       ...
# 179        2
# 180        3
# 181        4
# 182        5
# 183        6
#
# [184 rows x 8 columns]

# %% [markdown]
# #### 计算weekday的weight
# + 按weekday聚合，计算weekday的均值
# + 实际weekday = weekday + 1

# %%
weekday_weight = total_balance[["weekday","total_purchase_amt","total_redeem_amt"]].groupby(["weekday"],as_index = False).mean()
weekday_weight
# Out:
#    weekday  total_purchase_amt  total_redeem_amt
# 0        0        3.273693e+08      3.456808e+08
# 1        1        3.340518e+08      3.221266e+08
# 2        2        3.213877e+08      3.181960e+08
# 3        3        3.146910e+08      2.821480e+08
# 4        4        2.492893e+08      2.680463e+08
# 5        5        1.958666e+08      1.840544e+08
# 6        6        1.966477e+08      2.093138e+08

# %%
#修改列名
weekday_weight.columns = ["weekday","purchase_weekday","redeem_weekday"]
weekday_weight
# Out:
#    weekday  purchase_weekday  redeem_weekday
# 0        0      3.273693e+08    3.456808e+08
# 1        1      3.340518e+08    3.221266e+08
# 2        2      3.213877e+08    3.181960e+08
# 3        3      3.146910e+08    2.821480e+08
# 4        4      2.492893e+08    2.680463e+08
# 5        5      1.958666e+08    1.840544e+08
# 6        6      1.966477e+08    2.093138e+08

# %%
#除以purchase,redeem均值，得到weekday factor
weekday_weight["purchase_weekday"] /= np.mean(total_balance["total_purchase_amt"])
weekday_weight["redeem_weekday"] /= np.mean(total_balance["total_redeem_amt"])
weekday_weight
# Out:
#    weekday  purchase_weekday  redeem_weekday
# 0        0          1.185411        1.257964
# 1        1          1.209608        1.172248
# 2        2          1.163752        1.157944
# 3        3          1.139503        1.026762
# 4        4          0.902682        0.975445
# 5        5          0.709237        0.669791
# 6        6          0.712065        0.761712

# %%
#将统计数据合并到原数据集，即在原数据集上添加purchase_weekday,redeem_weekday周期因子字段
total_balance = pd.merge(total_balance,weekday_weight,on = "weekday",how = "left")
total_balance
# Out:
#     report_date  total_purchase_amt  total_redeem_amt  year  month  day  week  \
# 0    2014-03-01           362865580         211279011  2014      3    1     9
# 1    2014-03-02           276202230         246199417  2014      3    2     9
# 2    2014-03-03           505305862         513017360  2014      3    3    10
# 3    2014-03-04           524146340         250562978  2014      3    4    10
# 4    2014-03-05           454295491         209072753  2014      3    5    10
# ..          ...                 ...               ...   ...    ...  ...   ...
# 179  2014-08-27           302194801         468164147  2014      8   27    35
# 180  2014-08-28           245082751         297893861  2014      8   28    35
# 181  2014-08-29           267554713         273756380  2014      8   29    35
# 182  2014-08-30           199708772         196374134  2014      8   30    35
# 183  2014-08-31           275090213         292943033  2014      8   31    35
#
#      weekday  purchase_weekday  redeem_weekday
# 0          5          0.709237        0.669791
# 1          6          0.712065        0.761712
# 2          0          1.185411        1.257964
# 3          1          1.209608        1.172248
# 4          2          1.163752        1.157944
# ..       ...               ...             ...
# 179        2          1.163752        1.157944
# 180        3          1.139503        1.026762
# 181        4          0.902682        0.975445
# 182        5          0.709237        0.669791
# 183        6          0.712065        0.761712
#
# [184 rows x 10 columns]

# %%
#分别统计周一到周日在1到31日出现的频次
weekday_count = total_balance[["weekday","day","report_date"]].groupby(["weekday","day"],as_index = False).count()
weekday_count
# Out:
#      weekday  day  report_date
# 0          0    2            1
# 1          0    3            1
# 2          0    4            1
# 3          0    5            1
# 4          0    7            2
# ..       ...  ...          ...
# 149        6   25            1
# 150        6   27            2
# 151        6   29            1
# 152        6   30            1
# 153        6   31            1
#
# [154 rows x 3 columns]

# %%
#weekday_count添加周期因子
weekday_count = pd.merge(weekday_count,weekday_weight,on = "weekday",how = "left")
weekday_count
# Out:
#      weekday  day  report_date  purchase_weekday  redeem_weekday
# 0          0    2            1          1.185411        1.257964
# 1          0    3            1          1.185411        1.257964
# 2          0    4            1          1.185411        1.257964
# 3          0    5            1          1.185411        1.257964
# 4          0    7            2          1.185411        1.257964
# ..       ...  ...          ...               ...             ...
# 149        6   25            1          0.712065        0.761712
# 150        6   27            2          0.712065        0.761712
# 151        6   29            1          0.712065        0.761712
# 152        6   30            1          0.712065        0.761712
# 153        6   31            1          0.712065        0.761712
#
# [154 rows x 5 columns]

# %%
#根据周期因子对purchase_weekday,redeem_weekday进行加权，获得day_factor
#day_factor = week_factor * （周一到周日在1至31日出现的频次/共有几个月）
weekday_count["purchase_day"] = weekday_count["purchase_weekday"] * weekday_count["report_date"]/len(np.unique(total_balance["month"]))
weekday_count["redeem_day"] = weekday_count["redeem_weekday"] * weekday_count["report_date"]/len(np.unique(total_balance["month"]))
weekday_count
# Out:
#      weekday  day  report_date  purchase_weekday  redeem_weekday  \
# 0          0    2            1          1.185411        1.257964
# 1          0    3            1          1.185411        1.257964
# 2          0    4            1          1.185411        1.257964
# 3          0    5            1          1.185411        1.257964
# 4          0    7            2          1.185411        1.257964
# ..       ...  ...          ...               ...             ...
# 149        6   25            1          0.712065        0.761712
# 150        6   27            2          0.712065        0.761712
# 151        6   29            1          0.712065        0.761712
# 152        6   30            1          0.712065        0.761712
# 153        6   31            1          0.712065        0.761712
#
#      purchase_day  redeem_day
# 0        0.197568    0.209661
# 1        0.197568    0.209661
# 2        0.197568    0.209661
# 3        0.197568    0.209661
# 4        0.395137    0.419321
# ..            ...         ...
# 149      0.118678    0.126952
# 150      0.237355    0.253904
# 151      0.118678    0.126952
# 152      0.118678    0.126952
# 153      0.118678    0.126952
#
# [154 rows x 7 columns]

# %%
#按day求和得到日期因子
day_rate = weekday_count.drop(["weekday","report_date","purchase_weekday","redeem_weekday"],axis =1).groupby(["day"],as_index =False).sum()
day_rate
# Out:
#     day  purchase_day  redeem_day
# 0     1      0.980451    0.963034
# 1     2      0.972816    0.996800
# 2     3      1.015888    0.985873
# 3     4      1.012700    1.050126
# 4     5      1.019458    0.992417
# 5     6      0.973279    0.975970
# 6     7      1.047666    1.057645
# 7     8      0.980451    0.963034
# 8     9      0.972816    0.996800
# 9    10      1.015888    0.985873
# 10   11      1.012700    1.050126
# 11   12      1.019458    0.992417
# 12   13      0.973279    0.975970
# 13   14      1.047666    1.057645
# 14   15      0.980451    0.963034
# 15   16      0.972816    0.996800
# 16   17      1.015888    0.985873
# 17   18      1.012700    1.050126
# 18   19      1.019458    0.992417
# 19   20      0.973279    0.975970
# 20   21      1.047666    1.057645
# 21   22      0.980451    0.963034
# 22   23      0.972816    0.996800
# 23   24      1.015888    0.985873
day_pred
# Out:
#     day  total_purchase_amt  total_redeem_amt  purchase_day  redeem_day  \
# 0     1        3.318261e+08      2.437791e+08      0.980451    0.963034
# 1     2        2.550589e+08      2.193092e+08      0.972816    0.996800
# 2     3        2.947971e+08      3.010781e+08      1.015888    0.985873
# 3     4        3.120176e+08      2.785948e+08      1.012700    1.050126
# 4     5        3.223549e+08      2.571989e+08      1.019458    0.992417
# 5     6        3.080774e+08      2.521549e+08      0.973279    0.975970
# 6     7        2.707662e+08      2.245401e+08      1.047666    1.057645
# 7     8        2.976859e+08      2.570267e+08      0.980451    0.963034
# 8     9        2.936426e+08      2.448103e+08      0.972816    0.996800
# 9    10        3.392448e+08      2.631022e+08      1.015888    0.985873
# 10   11        2.828475e+08      2.905753e+08      1.012700    1.050126
# 11   12        2.694670e+08      2.567880e+08      1.019458    0.992417
# 12   13        2.547901e+08      2.807566e+08      0.973279    0.975970
# 13   14        2.585589e+08      2.789841e+08      1.047666    1.057645
# 14   15        3.017145e+08      2.390468e+08      0.980451    0.963034
# 15   16        3.231958e+08      3.134922e+08      0.972816    0.996800
# 16   17        2.525090e+08      3.029843e+08      1.015888    0.985873
# 17   18        2.768047e+08      2.665385e+08      1.012700    1.050126
# 18   19        2.782770e+08      2.627955e+08      1.019458    0.992417
# 19   20        2.990983e+08      2.426087e+08      0.973279    0.975970
# 20   21        2.687144e+08      2.664210e+08      1.047666    1.057645
# 21   22        2.478735e+08      2.713016e+08      0.980451    0.963034
# 22   23        2.346763e+08      2.634138e+08      0.972816    0.996800
# 23   24        2.369525e+08      3.015848e+08      1.015888    0.985873
# 24   25        2.399682e+08      3.006089e+08      1.012700    1.050126
# 25   26        2.456032e+08      3.140413e+08      1.019458    0.992417
# 26   27        2.448770e+08      3.256881e+08      0.973279    0.975970
# 27   28        2.541698e+08      3.271957e+08      1.047666    1.057645
# 28   29        2.491809e+08      2.794673e+08      0.980451    0.963034
# 29   30        2.459959e+08      2.946751e+08      0.972816    0.996800
# 30   31        4.054202e+08      4.588734e+08      0.624369    0.619371
#
#    report_date
# 0   2014-09-01
# 1   2014-09-02
# 2   2014-09-03
# 3   2014-09-04
# 4   2014-09-05
# 5   2014-09-06
# 6   2014-09-07
# 7   2014-09-08
# 8   2014-09-09
# 9   2014-09-10
# 10  2014-09-11
# 11  2014-09-12
# 12  2014-09-13
# 13  2014-09-14
# 14  2014-09-15
# 15  2014-09-16
# 16  2014-09-17
# 17  2014-09-18
# 18  2014-09-19
# 19  2014-09-20
# 20  2014-09-21
# 21  2014-09-22
# 22  2014-09-23
# 23  2014-09-24
# 24  2014-09-25
# 25  2014-09-26
# 26  2014-09-27
# 27  2014-09-28
# 28  2014-09-29
# 29  2014-09-30
# 30         NaT

# %% [markdown]
# ## 基于base和周期因子预测结果

# %%
#添加weekday字段
day_pred["weekday"] = day_pred.report_date.dt.weekday
day_pred = day_pred[["report_date","weekday","total_purchase_amt","total_redeem_amt"]]
day_pred
# Out:
#    report_date  weekday  total_purchase_amt  total_redeem_amt
# 0   2014-09-01      0.0        3.318261e+08      2.437791e+08
# 1   2014-09-02      1.0        2.550589e+08      2.193092e+08
# 2   2014-09-03      2.0        2.947971e+08      3.010781e+08
# 3   2014-09-04      3.0        3.120176e+08      2.785948e+08
# 4   2014-09-05      4.0        3.223549e+08      2.571989e+08
# 5   2014-09-06      5.0        3.080774e+08      2.521549e+08
# 6   2014-09-07      6.0        2.707662e+08      2.245401e+08
# 7   2014-09-08      0.0        2.976859e+08      2.570267e+08
# 8   2014-09-09      1.0        2.936426e+08      2.448103e+08
# 9   2014-09-10      2.0        3.392448e+08      2.631022e+08
# 10  2014-09-11      3.0        2.828475e+08      2.905753e+08
# 11  2014-09-12      4.0        2.694670e+08      2.567880e+08
# 12  2014-09-13      5.0        2.547901e+08      2.807566e+08
# 13  2014-09-14      6.0        2.585589e+08      2.789841e+08
# 14  2014-09-15      0.0        3.017145e+08      2.390468e+08
# 15  2014-09-16      1.0        3.231958e+08      3.134922e+08
# 16  2014-09-17      2.0        2.525090e+08      3.029843e+08
# 17  2014-09-18      3.0        2.768047e+08      2.665385e+08
# 18  2014-09-19      4.0        2.782770e+08      2.627955e+08
# 19  2014-09-20      5.0        2.990983e+08      2.426087e+08
# 20  2014-09-21      6.0        2.687144e+08      2.664210e+08
# 21  2014-09-22      0.0        2.478735e+08      2.713016e+08
# 22  2014-09-23      1.0        2.346763e+08      2.634138e+08
# 23  2014-09-24      2.0        2.369525e+08      3.015848e+08
# 24  2014-09-25      3.0        2.399682e+08      3.006089e+08
# 25  2014-09-26      4.0        2.456032e+08      3.140413e+08
# 26  2014-09-27      5.0        2.448770e+08      3.256881e+08
# 27  2014-09-28      6.0        2.541698e+08      3.271957e+08
# 28  2014-09-29      0.0        2.491809e+08      2.794673e+08
# 29  2014-09-30      1.0        2.459959e+08      2.946751e+08
# 30         NaT      NaN        4.054202e+08      4.588734e+08

# %%
#合并weekday_weight
day_pred = pd.merge(day_pred,weekday_weight,on = "weekday",how = "left")
#day_pred
#考虑weekday factor
day_pred["total_purchase_amt"] *= day_pred["purchase_weekday"]
day_pred["total_redeem_amt"] *= day_pred["redeem_weekday"]
day_pred
# Out:
#    report_date  weekday  total_purchase_amt  total_redeem_amt  \
# 0   2014-09-01      0.0        3.933503e+08      3.066653e+08
# 1   2014-09-02      1.0        3.085214e+08      2.570847e+08
# 2   2014-09-03      2.0        3.430706e+08      3.486316e+08
# 3   2014-09-04      3.0        3.555449e+08      2.860506e+08
# 4   2014-09-05      4.0        2.909838e+08      2.508833e+08
# 5   2014-09-06      5.0        2.184999e+08      1.688910e+08
# 6   2014-09-07      6.0        1.928032e+08      1.710349e+08
# 7   2014-09-08      0.0        3.528802e+08      3.233303e+08
# 8   2014-09-09      1.0        3.551925e+08      2.869784e+08
# 9   2014-09-10      2.0        3.947967e+08      3.046577e+08
# 10  2014-09-11      3.0        3.223055e+08      2.983517e+08
# 11  2014-09-12      4.0        2.432429e+08      2.504825e+08
# 12  2014-09-13      5.0        1.807066e+08      1.880482e+08
# 13  2014-09-14      6.0        1.841108e+08      2.125055e+08
# 14  2014-09-15      0.0        3.576557e+08      3.007123e+08
# 15  2014-09-16      1.0        3.909404e+08      3.674905e+08
# 16  2014-09-17      2.0        2.938577e+08      3.508389e+08
# 17  2014-09-18      3.0        3.154197e+08      2.736716e+08
# 18  2014-09-19      4.0        2.511956e+08      2.563425e+08
# 19  2014-09-20      5.0        2.121316e+08      1.624970e+08
# 20  2014-09-21      6.0        1.913422e+08      2.029360e+08
# 21  2014-09-22      0.0        2.938320e+08      3.412876e+08
# 22  2014-09-23      1.0        2.838664e+08      3.087863e+08
# 23  2014-09-24      2.0        2.757539e+08      3.492184e+08
# 24  2014-09-25      3.0        2.734444e+08      3.086538e+08
# 25  2014-09-26      4.0        2.217015e+08      3.063300e+08
# 26  2014-09-27      5.0        1.736759e+08      2.181428e+08
# 27  2014-09-28      6.0        1.809855e+08      2.492289e+08
# 28  2014-09-29      0.0        2.953817e+08      3.515598e+08
# 29  2014-09-30      1.0        2.975587e+08      3.454322e+08
# 30         NaT      NaN                 NaN               NaN
#
#     purchase_weekday  redeem_weekday
# 0           1.185411        1.257964
# 1           1.209608        1.172248
# 2           1.163752        1.157944
# 3           1.139503        1.026762
# 4           0.902682        0.975445
# 5           0.709237        0.669791
# 6           0.712065        0.761712
# 7           1.185411        1.257964
# 8           1.209608        1.172248
# 9           1.163752        1.157944
# 10          1.139503        1.026762
# 11          0.902682        0.975445
# 12          0.709237        0.669791
# 13          0.712065        0.761712
# 14          1.185411        1.257964
# 15          1.209608        1.172248
# 16          1.163752        1.157944
# 17          1.139503        1.026762
# 18          0.902682        0.975445
# 19          0.709237        0.669791
# 20          0.712065        0.761712
# 21          1.185411        1.257964
# 22          1.209608        1.172248
# 23          1.163752        1.157944
# 24          1.139503        1.026762
# 25          0.902682        0.975445
# 26          0.709237        0.669791
# 27          0.712065        0.761712
# 28          1.185411        1.257964
# 29          1.209608        1.172248
# 30               NaN             NaN

# %%
#得到预测数据
day_pred = day_pred[["report_date","total_purchase_amt","total_redeem_amt"]].dropna()
day_pred["report_date"] = day_pred["report_date"].apply(lambda x:str(x).replace("-","")[:8])
day_pred
# Out:
#    report_date  total_purchase_amt  total_redeem_amt
# 0     20140901        3.933503e+08      3.066653e+08
# 1     20140902        3.085214e+08      2.570847e+08
# 2     20140903        3.430706e+08      3.486316e+08
# 3     20140904        3.555449e+08      2.860506e+08
# 4     20140905        2.909838e+08      2.508833e+08
# 5     20140906        2.184999e+08      1.688910e+08
# 6     20140907        1.928032e+08      1.710349e+08
# 7     20140908        3.528802e+08      3.233303e+08
# 8     20140909        3.551925e+08      2.869784e+08
# 9     20140910        3.947967e+08      3.046577e+08
# 10    20140911        3.223055e+08      2.983517e+08
# 11    20140912        2.432429e+08      2.504825e+08
# 12    20140913        1.807066e+08      1.880482e+08
# 13    20140914        1.841108e+08      2.125055e+08
# 14    20140915        3.576557e+08      3.007123e+08
# 15    20140916        3.909404e+08      3.674905e+08
# 16    20140917        2.938577e+08      3.508389e+08
# 17    20140918        3.154197e+08      2.736716e+08
# 18    20140919        2.511956e+08      2.563425e+08
# 19    20140920        2.121316e+08      1.624970e+08
# 20    20140921        1.913422e+08      2.029360e+08
# 21    20140922        2.938320e+08      3.412876e+08
# 22    20140923        2.838664e+08      3.087863e+08
# 23    20140924        2.757539e+08      3.492184e+08
# 24    20140925        2.734444e+08      3.086538e+08
# 25    20140926        2.217015e+08      3.063300e+08
# 26    20140927        1.736759e+08      2.181428e+08
# 27    20140928        1.809855e+08      2.492289e+08
# 28    20140929        2.953817e+08      3.515598e+08
# 29    20140930        2.975587e+08      3.454322e+08

# %%
#保存提交数据
day_pred.to_csv("./result_weekfactor.csv",header = None,index = None)
